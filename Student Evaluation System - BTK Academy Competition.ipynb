# %%
import numpy as np
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datathon-2024/sample_submission.csv
# /kaggle/input/datathon-2024/test_x.csv
# /kaggle/input/datathon-2024/train.csv

# %%
train = pd.read_csv("/kaggle/input/datathon-2024/train.csv")
test = pd.read_csv("/kaggle/input/datathon-2024/test_x.csv")
sample_submission = pd.read_csv("/kaggle/input/datathon-2024/sample_submission.csv")

# %%
train.columns
# Out:
# Index(['Basvuru Yili', 'Degerlendirme Puani', 'Cinsiyet', 'Dogum Tarihi',
#        'Dogum Yeri', 'Ikametgah Sehri', 'Universite Adi', 'Universite Turu',
#        'Burslu ise Burs Yuzdesi', 'Burs Aliyor mu?', 'Bölüm',
#        'Universite Kacinci Sinif', 'Universite Not Ortalamasi',
#        'Daha Once Baska Bir Universiteden Mezun Olmus', 'Lise Adi',
#        'Lise Adi Diger', 'Lise Sehir', 'Lise Turu', 'Lise Bolumu',
#        'Lise Bolum Diger', 'Lise Mezuniyet Notu',
#        'Baska Bir Kurumdan Burs Aliyor mu?', 'Burs Aldigi Baska Kurum',
#        'Baska Kurumdan Aldigi Burs Miktari', 'Anne Egitim Durumu',
#        'Anne Calisma Durumu', 'Anne Sektor', 'Baba Egitim Durumu',
#        'Baba Calisma Durumu', 'Baba Sektor', 'Kardes Sayisi',
#        'Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?',
#        'Uye Oldugunuz Kulubun Ismi',
#        'Profesyonel Bir Spor Daliyla Mesgul musunuz?',
#        'Spor Dalindaki Rolunuz Nedir?', 'Aktif olarak bir STK üyesi misiniz?',
# ...

# %%
for i in train.columns:
    print("Column Name: ",i)
    print(train[i].value_counts())
    print("\n\n")
    
#Dogum Tarihi,Dogum Yeri,Ikametgah Sehri,Bölüm
#Universite Adi,Lise Adi Diger,Lise Adi,Lise Sehir
# Out:
# Column Name:  Basvuru Yili
# Basvuru Yili
# 2021    11594
# 2017    10325
# 2015     7804
# 2020     7760
# 2022     7622
# 2019     7248
# 2014     6454
# 2016     5213
# 2018     1105
# Name: count, dtype: int64
#
#
#
# Column Name:  Degerlendirme Puani
# Degerlendirme Puani
# 28.0     2063
# 22.0     2041
# 18.0     1995
# 24.0     1785
# 12.0     1740
#          ...
# 83.0        2
# 102.0       2
# 85.0        2
# 89.0        1
# 95.0        1
# Name: count, Length: 97, dtype: int64
#
#
#
# Column Name:  Cinsiyet
# Cinsiyet
# Kadın                    32077
# Erkek                    22752
# ERKEK                    10012
# Belirtmek istemiyorum      115
# Name: count, dtype: int64
#
#
#
# Column Name:  Dogum Tarihi
# Dogum Tarihi
# 1/1/70 2:00         1655
# 1/1/00 0:00          179
# 1/1/01 0:00          154
# 1/1/1997             139
# 1/1/1998             129
#                     ...
# 20.04.2003 00:00       1
# 10.08.1998 00:00       1
# 31.10.2001 00:00       1
# ...

# %%
for i in test.columns:
    print("Column Name: ",i)
    print(test[i].value_counts())
    print("\n\n")
# Out:
# Column Name:  Basvuru Yili
# Basvuru Yili
# 2023    11049
# Name: count, dtype: int64
#
#
#
# Column Name:  Cinsiyet
# Cinsiyet
# Kadın                    6378
# Erkek                    4654
# Belirtmek istemiyorum      17
# Name: count, dtype: int64
#
#
#
# Column Name:  Dogum Tarihi
# Dogum Tarihi
# 1.01.2002 00:00     135
# 1.01.2001 00:00      98
# 1.01.2003 00:00      87
# 1.01.2000 00:00      78
# 1.01.2004 00:00      54
#                    ...
# 26.05.1999 00:00      1
# 12.11.1998 00:00      1
# 25.03.2003 00:00      1
# 6.05.1999 00:00       1
# 27.04.1999 00:00      1
# Name: count, Length: 2135, dtype: int64
#
#
#
# Column Name:  Dogum Yeri
# Dogum Yeri
# İstanbul      1814
# Ankara         603
# Diyarbakır     408
# Hatay          384
# Şanlıurfa      357
#               ...
# Yalova          14
# Bartın          14
# KKTC            10
# Bayburt          9
# Tunceli          9
# Name: count, Length: 83, dtype: int64
#
#
#
# Column Name:  Ikametgah Sehri
# ...

# %%
train['Cinsiyet'] = train['Cinsiyet'].replace({'ERKEK': 1, 'Erkek': 1, 'Kadın': 0,'Kız' : 0})
test['Cinsiyet'] = test['Cinsiyet'].replace({'ERKEK': 1, 'Erkek': 1, 'Kadın': 0,'Kız' : 0})
belirsiz_cinsiyetler = train[train['Cinsiyet'] == 'Belirtmek istemiyorum'].index
yarisi = len(belirsiz_cinsiyetler) // 2
yarisi = len(belirsiz_cinsiyetler) // 2
train.loc[belirsiz_cinsiyetler[:yarisi], 'Cinsiyet'] = 'Erkek'
train.loc[belirsiz_cinsiyetler[yarisi:], 'Cinsiyet'] = 'Kız'
belirsiz_cinsiyetler = test[test['Cinsiyet'] == 'Belirtmek istemiyorum'].index
yarisi = len(belirsiz_cinsiyetler) // 2
yarisi = len(belirsiz_cinsiyetler) // 2
test.loc[belirsiz_cinsiyetler[:yarisi], 'Cinsiyet'] = 'Erkek'
test.loc[belirsiz_cinsiyetler[yarisi:], 'Cinsiyet'] = 'Kız'
train['Cinsiyet'] = train['Cinsiyet'].replace({'ERKEK': 1, 'Erkek': 1, 'Kadın': 0,'Kız' : 0})
test['Cinsiyet'] = test['Cinsiyet'].replace({'ERKEK': 1, 'Erkek': 1, 'Kadın': 0,'Kız' : 0})

# %%
train["Universite Turu"] = train["Universite Turu"].replace({'Devlet': 1, 'DEVLET': 1, 'Özel': 0,'ÖZEL' : 0})
test["Universite Turu"] = test["Universite Turu"].replace({'Devlet': 1, 'DEVLET': 1, 'Özel': 0,'ÖZEL' : 0})

# %%
"""
train['Burslu ise Burs Yuzdesi'] = pd.cut(train['Burslu ise Burs Yuzdesi'], 
                                       bins=[0, 25, 50, 75, 100], 
                                       labels=['0-25', '25-50', '50-75', '75-100'], 
                                       include_lowest=True)

test['Burslu ise Burs Yuzdesi'] = pd.cut(test['Burslu ise Burs Yuzdesi'], 
                                       bins=[0, 25, 50, 75, 100], 
                                       labels=['0-25', '25-50', '50-75', '75-100'], 
                                       include_lowest=True)
"""
# Out:
# "\ntrain['Burslu ise Burs Yuzdesi'] = pd.cut(train['Burslu ise Burs Yuzdesi'], \n                                       bins=[0, 25, 50, 75, 100], \n                                       labels=['0-25', '25-50', '50-75', '75-100'], \n                                       include_lowest=True)\n\ntest['Burslu ise Burs Yuzdesi'] = pd.cut(test['Burslu ise Burs Yuzdesi'], \n                                       bins=[0, 25, 50, 75, 100], \n                                       labels=['0-25', '25-50', '50-75', '75-100'], \n                                       include_lowest=True)\n"

# %%
train["Burs Aliyor mu?"] = train["Burs Aliyor mu?"].replace({'Evet': 1, 'EVET': 1, 'evet': 1,'Hayır' : 0,'hayır' : 0})
test["Burs Aliyor mu?"] = test["Burs Aliyor mu?"].replace({'Evet': 1, 'EVET': 1, 'evet': 1,'Hayır' : 0,'hayır' : 0})
#train["Universite Kacinci Sinif"].value_counts()

# %%
train["Universite Not Ortalamasi"] = train["Universite Not Ortalamasi"].replace({'2.00 - 2.50': "2.50 ve altı", 
                                                           '1.80 - 2.49': "2.50 ve altı",
                                                          '1.80 - 2.49': "2.50 ve altı",
                                                          '1.00 - 2.50': "2.50 ve altı",
                                                           '0 - 1.79': "2.50 ve altı",
                                                           '3.00-2.50': "2.50 - 3.00", 
                                                           '2.50 - 2.99': "2.50 - 3.00",
                                                          '2.50 -3.00': "2.50 - 3.00",
                                                          '2.50 - 3.00': "2.50 - 3.00",
                                                           '3.00 - 3.50': "3.00 - 3.50",
                                                           '3.50-3': "3.00 - 3.50",
                                                          '3.00 - 3.49': "3.00 - 3.50",
                                                          '4-3.5': "3.50 - 4.00",
                                                           '4.0-3.5': "3.50 - 4.00",
                                                           '3.00 - 4.00': "3.50 - 4.00",
                                                           'ORTALAMA BULUNMUYOR': "2.50 ve altı",
                                                          'Not ortalaması yok': "2.50 ve altı",
                                                           'Hazırlığım': "2.50 ve altı",
                                                           'Ortalama bulunmuyor': "2.50 ve altı",
                                                           
                                                           })

test["Universite Not Ortalamasi"] = test["Universite Not Ortalamasi"].replace({'2.00 - 2.50': "2.50 ve altı", 
                                                           '1.80 - 2.49': "2.50 ve altı",
                                                          '1.80 - 2.49': "2.50 ve altı",
                                                          '1.00 - 2.50': "2.50 ve altı",
                                                           '0 - 1.79': "2.50 ve altı",
                                                           '3.00-2.50': "2.50 - 3.00", 
                                                           '2.50 - 2.99': "2.50 - 3.00",
                                                          '2.50 -3.00': "2.50 - 3.00",
                                                          '2.50 - 3.00': "2.50 - 3.00",
                                                           '3.00 - 3.50': "3.00 - 3.50",
                                                           '3.50-3': "3.00 - 3.50",
                                                          '3.00 - 3.49': "3.00 - 3.50",
                                                          '4-3.5': "3.50 - 4.00",
                                                           '4.0-3.5': "3.50 - 4.00",
                                                           '3.00 - 4.00': "3.50 - 4.00",
                                                           'ORTALAMA BULUNMUYOR': "2.50 ve altı",
                                                          'Not ortalaması yok': "2.50 ve altı",
                                                           'Hazırlığım': "2.50 ve altı",
                                                           'Ortalama bulunmuyor': "2.50 ve altı",
                                                           
                                                           })

# %%
train["Daha Once Baska Bir Universiteden Mezun Olmus"] = train["Daha Once Baska Bir Universiteden Mezun Olmus"].replace({'Evet': 1, 'Hayır': 0})
test["Daha Once Baska Bir Universiteden Mezun Olmus"] = test["Daha Once Baska Bir Universiteden Mezun Olmus"].replace({'Evet': 1, 'Hayır': 0})

# %%
test["Daha Once Baska Bir Universiteden Mezun Olmus"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
train["Universite Kacinci Sinif"] = train["Universite Kacinci Sinif"].replace(
    {'0': 'Hazırlık', 'Hazırlık': 'Hazırlık', 'hazırlık': 'Hazırlık'}
)
test["Universite Kacinci Sinif"] = test["Universite Kacinci Sinif"].replace(
    {'0': 'Hazırlık', 'Hazırlık': 'Hazırlık', 'hazırlık': 'Hazırlık'}
)

# %%
test["Lise Mezuniyet Notu"] = test["Lise Mezuniyet Notu"].replace({ "4.00-3.50" : "90 - 100",
                                                                   "3.00 - 4.00" : "80 - 100",
                                                                   "3.50-3.00" : "80 - 90",
                                                                   "3.50-3" : "80 - 90",
                                                                   "3.00-2.50" : "75 - 80",
                                                                   "2.50 ve altı" : "0 - 75"})
train["Lise Mezuniyet Notu"] = train["Lise Mezuniyet Notu"].replace({ "4.00-3.50" : "90 - 100",
                                                                   "3.00 - 4.00" : "80 - 100",
                                                                   "3.50-3.00" : "80 - 90",
                                                                   "3.50-3" : "80 - 90",
                                                                   "3.00-2.50" : "75 - 80",
                                                                   "2.50 ve altı" : "0 - 75"})

train["Lise Mezuniyet Notu"] = train["Lise Mezuniyet Notu"].replace({ "0 - 24" : "0 - 50",
                                                                   "25 - 49" : "0 - 50",
                                                                    "0 - 25" : "0 - 50",
                                                                   "44-0" : "0 - 50",
                                                                   "Not ortalaması yok" : "0 - 50",
                                                                   "25 - 50" : "0 - 50",
                                                                   
                                                                    "54-45" : "0 - 50",
                                                                   "0 - 75" : "50 - 75",
                                                                   "50 - 74" : "50 - 75",
                                                                   "69-55" : "50 - 75",
                                                                   "50 - 75" : "50 - 75",
                                                                    "75 - 80": "75 - 80",
                                                                     "84-70": "75 - 80",
                                                                     "80 - 90": "80 - 100",
                                                                     "75 - 100": "80 - 100",
                                                                     "100-85": "80 - 100",
                                                                     "90 - 100": "80 - 100",
                                                                     "80 - 100": "80 - 100",
                                                                    })

test["Lise Mezuniyet Notu"] = test["Lise Mezuniyet Notu"].replace({ "0 - 24" : "0 - 50",
                                                                   "25 - 49" : "0 - 50",
                                                                    "0 - 25" : "0 - 50",
                                                                   "44-0" : "0 - 50",
                                                                   "Not ortalaması yok" : "0 - 50",
                                                                   "25 - 50" : "0 - 50",
                                                                   
                                                                    "54-45" : "0 - 50",
                                                                   "0 - 75" : "50 - 75",
                                                                   "50 - 74" : "50 - 75",
                                                                   "69-55" : "50 - 75",
                                                                   "50 - 75" : "50 - 75",
                                                                    "75 - 80": "75 - 80",
                                                                     "84-70": "75 - 80",
                                                                     "80 - 90": "80 - 100",
                                                                     "75 - 100": "80 - 100",
                                                                     "100-85": "80 - 100",
                                                                     "90 - 100": "80 - 100",
                                                                     "80 - 100": "80 - 100",
                                                                    })

# %%
train["Baska Bir Kurumdan Burs Aliyor mu?"] = train["Baska Bir Kurumdan Burs Aliyor mu?"].replace({'Evet': 1, 'Hayır': 0})
test["Baska Bir Kurumdan Burs Aliyor mu?"] = test["Baska Bir Kurumdan Burs Aliyor mu?"].replace({'Evet': 1, 'Hayır': 0})

# %%
train["Anne Egitim Durumu"] = train["Anne Egitim Durumu"].replace({'İlkokul': "İlkokul Mezunu",
                                                                   'İlkokul Mezunu': "İlkokul Mezunu",
                                                                   'İLKOKUL MEZUNU': "İlkokul Mezunu",
                                                                   'Ortaokul': "Ortaokul Mezunu",
                                                                   'Ortaokul Mezunu': "Ortaokul Mezunu",
                                                                   'ORTAOKUL MEZUNU': "Ortaokul Mezunu",
                                                                   'Lise': "Lise Mezunu",
                                                                   'LİSE': "Lise Mezunu",
                                                                   'Lise Mezunu': "Lise Mezunu",
                                                                   'Üniversite': "Üniversite Mezunu",
                                                                   'ÜNİVERSİTE': "Üniversite Mezunu",
                                                                   'Üniversite Mezunu': "Üniversite Mezunu",
                                                                   'Yüksek Lisans': "Yüksek Lisans Mezunu",
                                                                   'YÜKSEK LİSANS': "Yüksek Lisans Mezunu",
                                                                   'Yüksek Lisans / Doktora': "Doktora Mezunu",
                                                                   'Doktora': "Doktora Mezunu",
                                                                   'Yüksek Lisans / Doktara': "Doktora Mezunu",
                                                                   'DOKTORA': "Doktora Mezunu",
                                                                   'Eğitimi yok': "Eğitimsiz",
                                                                   'EĞİTİM YOK': "Eğitimsiz",
                                                                   'Eğitim Yok': "Eğitimsiz",
                                                                   
                                                                  })

test["Anne Egitim Durumu"] = test["Anne Egitim Durumu"].replace({'İlkokul': "İlkokul Mezunu",
                                                                   'İlkokul Mezunu': "İlkokul Mezunu",
                                                                   'İLKOKUL MEZUNU': "İlkokul Mezunu",
                                                                   'Ortaokul': "Ortaokul Mezunu",
                                                                   'Ortaokul Mezunu': "Ortaokul Mezunu",
                                                                   'ORTAOKUL MEZUNU': "Ortaokul Mezunu",
                                                                   'Lise': "Lise Mezunu",
                                                                   'LİSE': "Lise Mezunu",
                                                                   'Lise Mezunu': "Lise Mezunu",
                                                                   'Üniversite': "Üniversite Mezunu",
                                                                   'ÜNİVERSİTE': "Üniversite Mezunu",
                                                                   'Üniversite Mezunu': "Üniversite Mezunu",
                                                                   'Yüksek Lisans': "Yüksek Lisans Mezunu",
                                                                   'YÜKSEK LİSANS': "Yüksek Lisans Mezunu",
                                                                   'Yüksek Lisans / Doktora': "Doktora Mezunu",
                                                                   'Doktora': "Doktora Mezunu",
                                                                   'Yüksek Lisans / Doktara': "Doktora Mezunu",
                                                                   'DOKTORA': "Doktora Mezunu",
                                                                   'Eğitimi yok': "Eğitimsiz",
                                                                   'EĞİTİM YOK': "Eğitimsiz",
                                                                   'Eğitim Yok': "Eğitimsiz",
                                                                   
                                                                  })

# %%
train["Anne Sektor"] = train["Anne Sektor"].replace({"0": "Çalışmıyor",
                                                    "-": "Çalışmıyor",
                                                     "Özel Sektör": "Özel Sektör",
                                                     "ÖZEL SEKTÖR": "Özel Sektör",
                                                     "KAMU": "Kamu",
                                                     "Kamu": "Kamu",
                                                     "Diğer": "Diğer",
                                                     "DİĞER": "Diğer",
                                                    })

test["Anne Sektor"] = test["Anne Sektor"].replace({"0": "Çalışmıyor",
                                                    "-": "Çalışmıyor",
                                                     "Özel Sektör": "Özel Sektör",
                                                     "ÖZEL SEKTÖR": "Özel Sektör",
                                                     "KAMU": "Kamu",
                                                     "Kamu": "Kamu",
                                                     "Diğer": "Diğer",
                                                     "DİĞER": "Diğer",
                                                    })

# %%
train["Baba Egitim Durumu"] = train["Baba Egitim Durumu"].replace({'İlkokul': "İlkokul Mezunu",
                                                                   'İLKOKUL MEZUNU': "İlkokul Mezunu",
                                                                   'İlkokul Mezunu': "İlkokul Mezunu",
                                                                   'Ortaokul': "Ortaokul Mezunu",
                                                                   'Ortaokul Mezunu': "Ortaokul Mezunu",
                                                                   'ORTAOKUL MEZUNU': "Ortaokul Mezunu",
                                                                   'Lise': "Lise Mezunu",
                                                                   'LİSE': "Lise Mezunu",
                                                                   'Lise Mezunu': "Lise Mezunu",
                                                                   'Üniversite': "Üniversite Mezunu",
                                                                   'ÜNİVERSİTE': "Üniversite Mezunu",
                                                                   'Üniversite Mezunu': "Üniversite Mezunu",
                                                                   'Yüksek Lisans': "Yüksek Lisans Mezunu",
                                                                   'YÜKSEK LİSANS': "Yüksek Lisans Mezunu",
                                                                   'Yüksek Lisans / Doktora': "Doktora Mezunu",
                                                                   'Doktora': "Doktora Mezunu",
                                                                   'Yüksek Lisans / Doktara': "Doktora Mezunu",
                                                                   'DOKTORA': "Doktora Mezunu",
                                                                   'Eğitimi yok': "Eğitimsiz",
                                                                   'EĞİTİM YOK': "Eğitimsiz",
                                                                   'Eğitim Yok': "Eğitimsiz",
                                                                   '0' : "Eğitimsiz"
                                                                  })


                                              
test["Baba Egitim Durumu"] = test["Baba Egitim Durumu"].replace({'İlkokul': "İlkokul Mezunu",
                                                                   'İLKOKUL MEZUNU': "İlkokul Mezunu",
                                                                   'İlkokul Mezunu': "İlkokul Mezunu",
                                                                   'Ortaokul': "Ortaokul Mezunu",
                                                                   'Ortaokul Mezunu': "Ortaokul Mezunu",
                                                                   'ORTAOKUL MEZUNU': "Ortaokul Mezunu",
                                                                   'Lise': "Lise Mezunu",
                                                                   'LİSE': "Lise Mezunu",
                                                                   'Lise Mezunu': "Lise Mezunu",
                                                                   'Üniversite': "Üniversite Mezunu",
                                                                   'ÜNİVERSİTE': "Üniversite Mezunu",
                                                                   'Üniversite Mezunu': "Üniversite Mezunu",
                                                                   'Yüksek Lisans': "Yüksek Lisans Mezunu",
                                                                   'YÜKSEK LİSANS': "Yüksek Lisans Mezunu",
                                                                   'Yüksek Lisans / Doktora': "Doktora Mezunu",
                                                                   'Doktora': "Doktora Mezunu",
                                                                   'Yüksek Lisans / Doktara': "Doktora Mezunu",
                                                                   'DOKTORA': "Doktora Mezunu",
                                                                   'Eğitimi yok': "Eğitimsiz",
                                                                   'EĞİTİM YOK': "Eğitimsiz",
                                                                   'Eğitim Yok': "Eğitimsiz",
                                                                   '0' : "Eğitimsiz"
                                                                  })

# %%
train["Baba Sektor"] = train["Baba Sektor"].replace({"0": "Çalışmıyor",
                                                    "-": "Çalışmıyor",
                                                     "Özel Sektör": "Özel Sektör",
                                                     "ÖZEL SEKTÖR": "Özel Sektör",
                                                     "KAMU": "Kamu",
                                                     "Kamu": "Kamu",
                                                     "Diğer": "Diğer",
                                                     "DİĞER": "Diğer",
                                                    })

test["Baba Sektor"] = test["Baba Sektor"].replace({"0": "Çalışmıyor",
                                                    "-": "Çalışmıyor",
                                                     "Özel Sektör": "Özel Sektör",
                                                     "ÖZEL SEKTÖR": "Özel Sektör",
                                                     "KAMU": "Kamu",
                                                     "Kamu": "Kamu",
                                                     "Diğer": "Diğer",
                                                     "DİĞER": "Diğer",
                                                    })

# %%
train["Kardes Sayisi"] = train["Kardes Sayisi"].replace({'Kardeş Sayısı 1 Ek Bilgi Aile Hk. Anne Vefat': 1.0})
test["Kardes Sayisi"] = test["Kardes Sayisi"].replace({'Kardeş Sayısı 1 Ek Bilgi Aile Hk. Anne Vefat': 1.0})
train['Kardes Sayisi'] = train['Kardes Sayisi'].astype(float)
test['Kardes Sayisi'] = test['Kardes Sayisi'].astype(float)

# %%
train["Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?"] = train["Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?"].replace({'Evet': 1.0,'Hayır': 0.0})
test["Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?"] = test["Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?"].replace({'Evet': 1.0,'Hayır': 0.0})

# %%
train["Profesyonel Bir Spor Daliyla Mesgul musunuz?"] = train["Profesyonel Bir Spor Daliyla Mesgul musunuz?"].replace({'Evet': 1.0,'Hayır': 0.0})
test["Profesyonel Bir Spor Daliyla Mesgul musunuz?"] = test["Profesyonel Bir Spor Daliyla Mesgul musunuz?"].replace({'Evet': 1.0,'Hayır': 0.0})

# %%
train["Spor Dalindaki Rolunuz Nedir?"] = train["Spor Dalindaki Rolunuz Nedir?"].replace({"0": "Spor Yapmıyorum",
                                                    "-": "Spor Yapmıyorum",
                                                     "Lider/Kaptan": "Lider",
                                                     "Kaptan": "Lider",
                                                     "KAPTAN / LİDER": "Lider",
                                                     "Takım Oyuncusu": "Takım Oyuncusu",
                                                     "Bireysel": "Bireysel",
                                                     "DİĞER": "Diğer",
                                                     "Diğer": "Diğer",                            
                                                    })

test["Spor Dalindaki Rolunuz Nedir?"] = test["Spor Dalindaki Rolunuz Nedir?"].replace({"0": "Spor Yapmıyorum",
                                                    "-": "Spor Yapmıyorum",
                                                     "Lider/Kaptan": "Lider",
                                                     "Kaptan": "Lider",
                                                     "KAPTAN / LİDER": "Lider",
                                                     "Takım Oyuncusu": "Takım Oyuncusu",
                                                     "Bireysel": "Bireysel",
                                                     "DİĞER": "Diğer",
                                                     "Diğer": "Diğer",                            
                                                    })

# %%
train["Aktif olarak bir STK üyesi misiniz?"] = train["Aktif olarak bir STK üyesi misiniz?"].replace({'Evet': 1.0,'Hayır': 0.0})
test["Aktif olarak bir STK üyesi misiniz?"] = test["Aktif olarak bir STK üyesi misiniz?"].replace({'Evet': 1.0,'Hayır': 0.0})

# %%
train["Stk Projesine Katildiniz Mi?"] = train["Stk Projesine Katildiniz Mi?"].replace({'Evet': 1.0,'Hayır': 0.0})
test["Stk Projesine Katildiniz Mi?"] = test["Stk Projesine Katildiniz Mi?"].replace({'Evet': 1.0,'Hayır': 0.0})

# %%
train["Girisimcilikle Ilgili Deneyiminiz Var Mi?"] = train["Girisimcilikle Ilgili Deneyiminiz Var Mi?"].replace({'Evet': 1.0,'Hayır': 0.0})
test["Girisimcilikle Ilgili Deneyiminiz Var Mi?"] = test["Girisimcilikle Ilgili Deneyiminiz Var Mi?"].replace({'Evet': 1.0,'Hayır': 0.0})

# %%
train["Ingilizce Biliyor musunuz?"] = train["Ingilizce Biliyor musunuz?"].replace({'Evet': 1.0,'Hayır': 0.0})
test["Ingilizce Biliyor musunuz?"] = test["Ingilizce Biliyor musunuz?"].replace({'Evet': 1.0,'Hayır': 0.0})

# %%
train["Ingilizce Seviyeniz?"] = train["Ingilizce Seviyeniz?"].replace({'0': "Bilmiyorum"})
test["Ingilizce Seviyeniz?"] = test["Ingilizce Seviyeniz?"].replace({'0': "Bilmiyorum"})

# %%
train["Lise Turu"] = train["Lise Turu"].replace({"Anadolu Lisesi": "Anadolu Lisesi",
                                                   "Anadolu lisesi": "Anadolu Lisesi",
                                                   "Fen Lisesi": "Fen Lisesi",
                                                   "Fen lisesi": "Fen Lisesi",
                                                   "Devlet": "Devlet Lisesi",
                                                   "Düz lise": "Devlet Lisesi",
                                                   "Meslek lisesi": "Devlet Lisesi",
                                                   "Düz Lise": "Devlet Lisesi",
                                                   "Meslek": "Devlet Lisesi",
                                                   "İmam Hatip Lisesi": "Devlet Lisesi",
                                                   "Meslek lisesi": "Devlet Lisesi",
                                                   "Meslek Lisesi": "Devlet Lisesi",
                                                   "Özel": "Özel Lise",
                                                   "Özel Lisesi": "Özel Lise",
                                                   "Özel lisesi": "Özel Lise",
                                                   "Özel Lise": "Özel Lise",
                                                   "Diğer": "Diğer",                    
                                                    })
test["Lise Turu"] = test["Lise Turu"].replace({"Anadolu Lisesi": "Anadolu Lisesi",
                                                   "Anadolu lisesi": "Anadolu Lisesi",
                                                   "Fen Lisesi": "Fen Lisesi",
                                                   "Fen lisesi": "Fen Lisesi",
                                                   "Devlet": "Devlet Lisesi",
                                                   "Düz lise": "Devlet Lisesi",
                                                   "Meslek lisesi": "Devlet Lisesi",
                                                   "Düz Lise": "Devlet Lisesi",
                                                   "Meslek": "Devlet Lisesi",
                                                   "Meslek Lisesi": "Devlet Lisesi",
                                                   "İmam Hatip Lisesi": "Devlet Lisesi",
                                                   "Meslek lisesi": "Devlet Lisesi",
                                                   "Özel": "Özel Lise",
                                                   "Özel Lisesi": "Özel Lise",
                                                   "Özel lisesi": "Özel Lise",
                                                   "Özel Lise": "Özel Lise",
                                                   "Diğer": "Diğer",                    
                                                    })

# %%
train["Lise Turu"].value_counts()
# Out:
# Lise Turu
# Devlet Lisesi     20865
# Anadolu Lisesi    20369
# Diğer             13184
# Özel Lise          7041
# Fen Lisesi         2819
# Name: count, dtype: int64

# %%
"""
import pandas as pd
import re
from collections import Counter




# Metin temizleme: Küçük harfe çevirme ve gereksiz karakterleri kaldırma
train['Cleaned_Text'] = train['Burs Aldigi Baska Kurum'].astype(str).str.lower().str.replace(r'[^\w\s]', '', regex=True)

# Tüm metinleri birleştir
all_text = ' '.join(train['Cleaned_Text'])

# Kelimeleri ayır
words = all_text.split()

# Kelime frekanslarını hesapla
word_counts = Counter(words)

# Sıklığa göre sıralama
sorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

# Kelime frekanslarını ve gruplamalarını göster
print("Kelime Frekansları:")
for word, count in sorted_word_counts:
    print(f"{word}: {count}")

# Örneğin frekansı 2'den fazla olan kelimeleri gruplamak
threshold = 2
frequent_words = {word: count for word, count in word_counts.items() if count > threshold}

print("\nBelirli Bir Eşik Değerine Göre Gruplama (Frekansı 2'den fazla olanlar):")
print(frequent_words)
"""
# Out:
# '\nimport pandas as pd\nimport re\nfrom collections import Counter\n\n\n\n\n# Metin temizleme: Küçük harfe çevirme ve gereksiz karakterleri kaldırma\ntrain[\'Cleaned_Text\'] = train[\'Burs Aldigi Baska Kurum\'].astype(str).str.lower().str.replace(r\'[^\\w\\s]\', \'\', regex=True)\n\n# Tüm metinleri birleştir\nall_text = \' \'.join(train[\'Cleaned_Text\'])\n\n# Kelimeleri ayır\nwords = all_text.split()\n\n# Kelime frekanslarını hesapla\nword_counts = Counter(words)\n\n# Sıklığa göre sıralama\nsorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)\n\n# Kelime frekanslarını ve gruplamalarını göster\nprint("Kelime Frekansları:")\nfor word, count in sorted_word_counts:\n    print(f"{word}: {count}")\n\n# Örneğin frekansı 2\'den fazla olan kelimeleri gruplamak\nthreshold = 2\nfrequent_words = {word: count for word, count in word_counts.items() if count > threshold}\n\nprint("\nBelirli Bir Eşik Değerine Göre Gruplama (Frekansı 2\'den fazla olanlar):")\nprint(freq
# ...

# %%
"""
import pandas as pd


# Anahtar kelimeler ve kategoriler
kategori_dict = {
    'Kredi ve Burs': ['kyk', 'kredi', 'bursu', 'öğrenim', 'burs', 'geri', 'ödemeli', 'kredisi', 'destekleme', 'burslar', 'öğrenim kredisi'],
    'Eğitim ve Üniversiteler': ['üniversitesi', 'üniversite', 'odtü', 'bilkent', 'sabancı', 'koç', 'boğaziçi', 'itü', 'üniversiteli', 'yükseköğrenim', 'eğitim', 'öğrenci'],
    'Vakfılar ve Dernekler': ['vakfı', 'derneği', 'vakfi', 'çağdaş', 'gençlik', 'spor', 'eğitim vakfı', 'tog', 'çydd', 'burs vakfı', 'vehbi', 'enka', 'elginkan'],
    'Devlet ve Kamu Kurumları': ['devlet', 'başbakanlık', 'bakanlığı', 'müdürlüğü', 'belediyesi', 'milli', 'tc', 'yök', 'meb', 'kamu', 'devlet bursu', 'devletkyk'],
    'Şehirler ve Bölgeler': ['istanbul', 'anadolu', 'izmir', 'mersin', 'adana', 'kayseri', 'konya', 'bursa', 'eskişehir', 'kocaeli', 'malatya', 'antalya', 'ardahan'],
    'Özel Sektör ve Şirketler': ['holding', 'zorlu', 'rönesans', 'sabanci', 'siemens', 'borusan', 'doğan', 'elidor', 'siemens', 'teknosa', 'teknoloji', 'inşaat', 'sanayi', 'tekstil'],
    'Toplum ve Sosyal Yardımlar': ['bursiyerleri', 'gönüllüleri', 'burslu', 'dayanışma', 'yardım', 'hayır', 'bursiyeriyim', 'bursiyerliği', 'gönüllü', 'kadınlar', 'genç', 'toplum', 'bursiyer'],
    'Özel Adlar': ['mehmet', 'vehbi', 'ihsan', 'ahmet', 'abdullah', 'hacı', 'hasan', 'hüseyin', 'turgutlu', 'terzioğlu', 'doğramacı', 'ibrahim', 'yavuz']
}

# Anahtar kelimeleri ve diğerlerini sınıflandırma
def categorize_value(value):
    if pd.isna(value):  # Eksik değerleri kontrol et
        return 'Diğer'
    value_lower = str(value).lower()  # Değeri küçük harfe çevir
    for category, keywords in kategori_dict.items():
        if any(keyword.lower() in value_lower for keyword in keywords):
            return category
    return 'Diğer'
# DataFrame'e kategori ekleme
train['Burs Aldigi Baska Kurum'] = train['Burs Aldigi Baska Kurum'].apply(categorize_value)

"""
# Out:
# "\nimport pandas as pd\n\n\n# Anahtar kelimeler ve kategoriler\nkategori_dict = {\n    'Kredi ve Burs': ['kyk', 'kredi', 'bursu', 'öğrenim', 'burs', 'geri', 'ödemeli', 'kredisi', 'destekleme', 'burslar', 'öğrenim kredisi'],\n    'Eğitim ve Üniversiteler': ['üniversitesi', 'üniversite', 'odtü', 'bilkent', 'sabancı', 'koç', 'boğaziçi', 'itü', 'üniversiteli', 'yükseköğrenim', 'eğitim', 'öğrenci'],\n    'Vakfılar ve Dernekler': ['vakfı', 'derneği', 'vakfi', 'çağdaş', 'gençlik', 'spor', 'eğitim vakfı', 'tog', 'çydd', 'burs vakfı', 'vehbi', 'enka', 'elginkan'],\n    'Devlet ve Kamu Kurumları': ['devlet', 'başbakanlık', 'bakanlığı', 'müdürlüğü', 'belediyesi', 'milli', 'tc', 'yök', 'meb', 'kamu', 'devlet bursu', 'devletkyk'],\n    'Şehirler ve Bölgeler': ['istanbul', 'anadolu', 'izmir', 'mersin', 'adana', 'kayseri', 'konya', 'bursa', 'eskişehir', 'kocaeli', 'malatya', 'antalya', 'ardahan'],\n    'Özel Sektör ve Şirketler': ['holding', 'zorlu', 'rönesans', 'sabanci', 'siemens', 'borusan', 'do
# ...

# %%
train["Burs Aldigi Baska Kurum"].value_counts()
# Out:
# Burs Aldigi Baska Kurum
# -                                 4711
# KYK                               2969
# Kyk                               2918
# kyk                                758
# Kredi ve Yurtlar Kurumu            624
#                                   ...
# Ataşehir Rotary Klubü                1
# galatasaray eğitim derneği           1
# Young Guru Academy                   1
# İelder                               1
# Odtü İstanbul Mezunlar Derneği       1
# Name: count, Length: 3959, dtype: int64

# %%
train["Dogum Tarihi"].value_counts()
# Out:
# Dogum Tarihi
# 1/1/70 2:00         1655
# 1/1/00 0:00          179
# 1/1/01 0:00          154
# 1/1/1997             139
# 1/1/1998             129
#                     ...
# 20.04.2003 00:00       1
# 10.08.1998 00:00       1
# 31.10.2001 00:00       1
# 14.08.1998 00:00       1
# 5.02.2003 00:00        1
# Name: count, Length: 13498, dtype: int64

# %%
train['Dogum Yili'] = pd.to_datetime(train['Dogum Tarihi'], errors='coerce').dt.year
test['Dogum Yili'] = pd.to_datetime(test['Dogum Tarihi'], errors='coerce').dt.year
del(train['Dogum Tarihi'])
del(test['Dogum Tarihi'])

# %%
train['Dogum Yili']
# Out:
# 0        1994.0
# 1        1993.0
# 2        1986.0
# 3        1991.0
# 4           NaN
#           ...
# 65120       NaN
# 65121       NaN
# 65122       NaN
# 65123       NaN
# 65124       NaN
# Name: Dogum Yili, Length: 65125, dtype: float64

# %%
ortalama_dogum_yili = train['Dogum Yili'].mean()
ortalama_tam = int(ortalama_dogum_yili)
train['Dogum Yili'].fillna(ortalama_tam, inplace=True)

ortalama_dogum_yili = test['Dogum Yili'].mean()
ortalama_tam = int(ortalama_dogum_yili)
test['Dogum Yili'].fillna(ortalama_tam, inplace=True)

# %%
test['Dogum Yili'].value_counts()
# Out:
# Dogum Yili
# 2002    2779
# 2001    2448
# 2003    2302
# 2000    1485
# 2004    1220
# 1999     660
# 1998     119
# 2005      36
# Name: count, dtype: int64

# %%
test['Dogum Yili'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11049 entries, 0 to 11048
# Series name: Dogum Yili
# Non-Null Count  Dtype
# --------------  -----
# 11049 non-null  int32
# dtypes: int32(1)
# memory usage: 43.3 KB

# %%
train['Dogum Yili'].value_counts()
# Out:
# Dogum Yili
# 1995.0    48708
# 1997.0     3200
# 1996.0     2896
# 1998.0     2440
# 1994.0     2170
# 1993.0     1727
# 1992.0     1204
# 1999.0     1061
# 1991.0      731
# 2000.0      493
# 1990.0      238
# 1989.0       60
# 1970.0       44
# 2001.0       36
# 1988.0       31
# 1987.0       23
# 1986.0       18
# 2017.0       11
# 1984.0        6
# 2002.0        4
# 1985.0        4
# 1983.0        4
# 1977.0        2
# 1976.0        2
# 1979.0        2
# 1980.0        2
# 2021.0        1
# 2011.0        1
# 1929.0        1
# 1982.0        1
# 1972.0        1
# 1895.0        1
# 1944.0        1
# 2016.0        1
# Name: count, dtype: int64

# %%
"""
del(train["Dogum Tarihi"])
del(test["Dogum Tarihi"])
del(train["Dogum Yeri"])
del(test["Dogum Yeri"])
del(train["Ikametgah Sehri"])
del(test["Ikametgah Sehri"])
del(train["Universite Adi"])
del(test["Universite Adi"])
del(train["Bölüm"])
del(test["Bölüm"])
del(train["Lise Adi"])
del(test["Lise Adi"])
del(train["Lise Adi Diger"])
del(test["Lise Adi Diger"])
del(train["Lise Sehir"])
del(test["Lise Sehir"])
del(train["Lise Bolumu"])
del(test["Lise Bolumu"])
del(train["Lise Bolum Diger"])
del(test["Lise Bolum Diger"])
del(train["Uye Oldugunuz Kulubun Ismi"])
del(test["Uye Oldugunuz Kulubun Ismi"])
del(train["Hangi STK'nin Uyesisiniz?"])
del(test["Hangi STK'nin Uyesisiniz?"])
del(train["Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?"])
del(test["Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?"])
del(train["Daha Önceden Mezun Olunduysa, Mezun Olunan Üniversite"])
del(test["Daha Önceden Mezun Olunduysa, Mezun Olunan Üniversite"])
del(train["Baska Kurumdan Aldigi Burs Miktari"])
del(test["Baska Kurumdan Aldigi Burs Miktari"])

del(train["Burs Aldigi Baska Kurum"])
del(test["Burs Aldigi Baska Kurum"])
"""
# Out:
# '\ndel(train["Dogum Tarihi"])\ndel(test["Dogum Tarihi"])\ndel(train["Dogum Yeri"])\ndel(test["Dogum Yeri"])\ndel(train["Ikametgah Sehri"])\ndel(test["Ikametgah Sehri"])\ndel(train["Universite Adi"])\ndel(test["Universite Adi"])\ndel(train["Bölüm"])\ndel(test["Bölüm"])\ndel(train["Lise Adi"])\ndel(test["Lise Adi"])\ndel(train["Lise Adi Diger"])\ndel(test["Lise Adi Diger"])\ndel(train["Lise Sehir"])\ndel(test["Lise Sehir"])\ndel(train["Lise Bolumu"])\ndel(test["Lise Bolumu"])\ndel(train["Lise Bolum Diger"])\ndel(test["Lise Bolum Diger"])\ndel(train["Uye Oldugunuz Kulubun Ismi"])\ndel(test["Uye Oldugunuz Kulubun Ismi"])\ndel(train["Hangi STK\'nin Uyesisiniz?"])\ndel(test["Hangi STK\'nin Uyesisiniz?"])\ndel(train["Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?"])\ndel(test["Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?"])\ndel(train["Daha Önceden Mezun Olunduysa, Mezun Olunan Üniversite"])\ndel(test["Daha Önceden Mezun Olunduysa, Mezun Olunan Üniversite"])\ndel(tra
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
"""
    pd.set_option('display.max_rows', None): 
    Bu ayar, tüm satırların görüntülenmesine olanak tanır.
    Eğer çok fazla satır varsa hepsini görmek için kullanışlıdır.

Eğer belirli bir satır sayısını göstermek isterseniz,
örneğin ilk 100 satırı göstermek için pd.set_option('display.max_rows', 100)
şeklinde de ayarlayabilirsiniz.
"""
pd.reset_option('display.max_rows')

# %%
if pd.api.types.is_categorical_dtype(train['Burslu ise Burs Yuzdesi']):
    train['Burslu ise Burs Yuzdesi'] = train['Burslu ise Burs Yuzdesi'].cat.add_categories('Bilinmiyor')

train['Burslu ise Burs Yuzdesi'] = train['Burslu ise Burs Yuzdesi'].fillna('Bilinmiyor')

# %%
if pd.api.types.is_categorical_dtype(test['Burslu ise Burs Yuzdesi']):
    test['Burslu ise Burs Yuzdesi'] = test['Burslu ise Burs Yuzdesi'].cat.add_categories('Bilinmiyor')

test['Burslu ise Burs Yuzdesi'] = test['Burslu ise Burs Yuzdesi'].fillna('Bilinmiyor')

# %%
train["Degerlendirme Puani"].fillna(train["Degerlendirme Puani"].mean(), inplace=True)

# %%
train["Universite Kacinci Sinif"].value_counts()
# Out:
# Universite Kacinci Sinif
# 2                21773
# 3                16956
# 4                13113
# 1                10260
# Hazırlık          1311
# 5                  961
# Mezun              178
# 6                  177
# Yüksek Lisans       15
# Tez                  7
# Name: count, dtype: int64

# %%
train["Universite Kacinci Sinif"] = train["Universite Kacinci Sinif"].fillna("1")

# %%
for i in train.columns:
    
    sex_counts = train[i].value_counts(normalize=True)
    num_missing = train[i].isna().sum()

    if num_missing > 0:
        fill_values = np.random.choice(sex_counts.index, size=num_missing, p=sex_counts.values)
        train.loc[train[i].isna(), i] = fill_values

# %%
for i in train.columns:
    print("Column Name: ",i)
    print(train[i].value_counts())
    print("\n\n")
# Out:
# Column Name:  Basvuru Yili
# Basvuru Yili
# 2021    11594
# 2017    10325
# 2015     7804
# 2020     7760
# 2022     7622
# 2019     7248
# 2014     6454
# 2016     5213
# 2018     1105
# Name: count, dtype: int64
#
#
#
# Column Name:  Degerlendirme Puani
# Degerlendirme Puani
# 28.000000     2063
# 22.000000     2041
# 18.000000     1995
# 24.000000     1785
# 12.000000     1740
#               ...
# 100.000000       2
# 102.000000       2
# 89.000000        1
# 95.000000        1
# 32.086466        1
# Name: count, Length: 98, dtype: int64
#
#
#
# Column Name:  Cinsiyet
# Cinsiyet
# 1.0    32905
# 0.0    32220
# Name: count, dtype: int64
#
#
#
# Column Name:  Dogum Yeri
# Dogum Yeri
# İstanbul             8788
# Ankara               4086
# İzmir                2198
# Istanbul             1912
# Bursa                1831
#                      ...
# UZUNKÖPRÜ EDİRNE        1
# Çamlıyayla              1
# ANKARA / ALTINDAĞ       1
# ERZURUM-İSPİR           1
# ...

# %%
nan_counts = train.isna().sum()

for column, count in nan_counts.items():
    print(f"'{column}' sütununda {count} NaN değeri var.")
    print("\n\n")
# Out:
# 'Basvuru Yili' sütununda 0 NaN değeri var.
#
#
#
# 'Degerlendirme Puani' sütununda 0 NaN değeri var.
#
#
#
# 'Cinsiyet' sütununda 0 NaN değeri var.
#
#
#
# 'Dogum Yeri' sütununda 0 NaN değeri var.
#
#
#
# 'Ikametgah Sehri' sütununda 0 NaN değeri var.
#
#
#
# 'Universite Adi' sütununda 0 NaN değeri var.
#
#
#
# 'Universite Turu' sütununda 0 NaN değeri var.
#
#
#
# 'Burslu ise Burs Yuzdesi' sütununda 0 NaN değeri var.
#
#
#
# 'Burs Aliyor mu?' sütununda 0 NaN değeri var.
#
#
#
# 'Bölüm' sütununda 0 NaN değeri var.
#
#
#
# 'Universite Kacinci Sinif' sütununda 0 NaN değeri var.
#
#
#
# 'Universite Not Ortalamasi' sütununda 0 NaN değeri var.
#
#
#
# 'Daha Once Baska Bir Universiteden Mezun Olmus' sütununda 0 NaN değeri var.
#
#
#
# 'Lise Adi' sütununda 0 NaN değeri var.
#
#
#
# 'Lise Adi Diger' sütununda 0 NaN değeri var.
#
#
#
# 'Lise Sehir' sütununda 0 NaN değeri var.
#
#
#
# 'Lise Turu' sütununda 0 NaN değeri var.
#
#
#
# 'Lise Bolumu' sütununda 0 NaN değeri var.
#
#
#
# ...

# %%
nan_counts = test.isna().sum()

for column, count in nan_counts.items():
    print(f"'{column}' sütununda {count} NaN değeri var.")
    print("\n\n")
# Out:
# 'Basvuru Yili' sütununda 0 NaN değeri var.
#
#
#
# 'Cinsiyet' sütununda 0 NaN değeri var.
#
#
#
# 'Dogum Yeri' sütununda 0 NaN değeri var.
#
#
#
# 'Ikametgah Sehri' sütununda 0 NaN değeri var.
#
#
#
# 'Universite Adi' sütununda 0 NaN değeri var.
#
#
#
# 'Universite Turu' sütununda 0 NaN değeri var.
#
#
#
# 'Burslu ise Burs Yuzdesi' sütununda 0 NaN değeri var.
#
#
#
# 'Burs Aliyor mu?' sütununda 0 NaN değeri var.
#
#
#
# 'Bölüm' sütununda 0 NaN değeri var.
#
#
#
# 'Universite Kacinci Sinif' sütununda 0 NaN değeri var.
#
#
#
# 'Universite Not Ortalamasi' sütununda 0 NaN değeri var.
#
#
#
# 'Daha Once Baska Bir Universiteden Mezun Olmus' sütununda 11049 NaN değeri var.
#
#
#
# 'Lise Adi' sütununda 0 NaN değeri var.
#
#
#
# 'Lise Adi Diger' sütununda 11049 NaN değeri var.
#
#
#
# 'Lise Sehir' sütununda 0 NaN değeri var.
#
#
#
# 'Lise Turu' sütununda 0 NaN değeri var.
#
#
#
# 'Lise Bolumu' sütununda 0 NaN değeri var.
#
#
#
# 'Lise Bolum Diger' sütununda 11049 NaN değeri var.
#
#
#
# ...

# %%
"""
Burslu ise Burs Yuzdesi
Daha Once Baska Bir Universiteden Mezun Olmus
Lise Adi Diger
Lise Bolum Diger
Uye Oldugunuz Kulubun Ismi
Stk Projesine Katildiniz Mi?
Ingilizce Seviyeniz?
Daha Önceden Mezun Olunduysa, Mezun Olunan Üniversite
"""
# Out:
# '\nBurslu ise Burs Yuzdesi\nDaha Once Baska Bir Universiteden Mezun Olmus\nLise Adi Diger\nLise Bolum Diger\nUye Oldugunuz Kulubun Ismi\nStk Projesine Katildiniz Mi?\nIngilizce Seviyeniz?\nDaha Önceden Mezun Olunduysa, Mezun Olunan Üniversite\n'

# %%
train["Basvuru Yili"] = train["Basvuru Yili"].replace({2014: 0.00,
                                                      2015: 0.10,
                                                      2016: 0.20,
                                                      2017: 0.30,
                                                      2018: 0.40,
                                                      2019: 0.50,
                                                      2020: 0.60,
                                                      2021: 0.70,
                                                      2022: 0.80})
test["Basvuru Yili"] = test["Basvuru Yili"].replace({2014: 0.00,
                                                      2015: 0.10,
                                                      2016: 0.20,
                                                      2017: 0.30,
                                                      2018: 0.40,
                                                      2019: 0.50,
                                                      2020: 0.60,
                                                      2021: 0.70,
                                                      2022: 0.80})


train["Burslu ise Burs Yuzdesi"] = train["Burslu ise Burs Yuzdesi"].replace({"Bilinmiyor": 0.00,
                                                      "0-25": 0.10,
                                                      "25-50": 0.20,
                                                      "50-75": 0.30,
                                                      "75-100": 0.40})

test["Burslu ise Burs Yuzdesi"] = test["Burslu ise Burs Yuzdesi"].replace({"Bilinmiyor": 0.00,
                                                      "0-25": 0.10,
                                                      "25-50": 0.20,
                                                      "50-75": 0.30,
                                                      "75-100": 0.40})


train["Universite Kacinci Sinif"] = train["Universite Kacinci Sinif"].replace({"Ön Lisans - Lisans": 0.0,
                                                      "Mezun": 0.10,
                                                      "Yüksek Lisans": 0.20})

test["Universite Kacinci Sinif"] = test["Universite Kacinci Sinif"].replace({"Ön Lisans - Lisans": 0.0,
                                                      "Mezun": 0.10,
                                                      "Yüksek Lisans": 0.20})

train["Universite Not Ortalamasi"] = train["Universite Not Ortalamasi"].replace({"2.50 - 3.00": 0.10,
                                                      "2.50 ve altı": 0.0,
                                                      "3.00 - 3.50": 0.20,
                                                      "3.50 - 4.00": 0.30 
                                                        })
test["Universite Not Ortalamasi"] = test["Universite Not Ortalamasi"].replace({"2.50 - 3.00": 0.10,
                                                      "2.50 ve altı": 0.0,
                                                      "3.00 - 3.50": 0.20,
                                                      "3.50 - 4.00": 0.30 
                                                        })
train["Lise Mezuniyet Notu"] = train["Lise Mezuniyet Notu"].replace({"0 - 50": 0.0,
                                                      "50 - 75": 0.10,
                                                      "75 - 80": 0.20,
                                                      "80 - 100": 0.30 
                                                        })
test["Lise Mezuniyet Notu"] = test["Lise Mezuniyet Notu"].replace({"0 - 50": 0.0,
                                                      "50 - 75": 0.10,
                                                      "75 - 80": 0.20,
                                                      "80 - 100": 0.30 
                                                        })
train["Anne Egitim Durumu"] = train["Anne Egitim Durumu"].replace({"Eğitimsiz": 0.0,
                                                      "İlkokul Mezunu": 0.10,
                                                      "Ortaokul Mezunu": 0.20,
                                                      "Lise Mezunu": 0.30,
                                                     "Üniversite Mezunu": 0.40,
                                                      "Yüksek Lisans Mezunu": 0.50,
                                                      "Doktora Mezunu": 0.60})

test["Anne Egitim Durumu"] = test["Anne Egitim Durumu"].replace({"Eğitimsiz": 0.0,
                                                      "İlkokul Mezunu": 0.10,
                                                      "Ortaokul Mezunu": 0.20,
                                                      "Lise Mezunu": 0.30,
                                                     "Üniversite Mezunu": 0.40,
                                                      "Yüksek Lisans Mezunu": 0.50,
                                                      "Doktora Mezunu": 0.60})

train["Baba Egitim Durumu"] = train["Baba Egitim Durumu"].replace({"Eğitimsiz": 0.0,
                                                      "İlkokul Mezunu": 0.10,
                                                      "Ortaokul Mezunu": 0.20,
                                                      "Lise Mezunu": 0.30,
                                                     "Üniversite Mezunu": 0.40,
                                                      "Yüksek Lisans Mezunu": 0.50,
                                                      "Doktora Mezunu": 0.60})

test["Baba Egitim Durumu"] = test["Baba Egitim Durumu"].replace({"Eğitimsiz": 0.0,
                                                      "İlkokul Mezunu": 0.10,
                                                      "Ortaokul Mezunu": 0.20,
                                                      "Lise Mezunu": 0.30,
                                                     "Üniversite Mezunu": 0.40,
                                                      "Yüksek Lisans Mezunu": 0.50,
                                                      "Doktora Mezunu": 0.60})


train["Ingilizce Seviyeniz?"] = train["Ingilizce Seviyeniz?"].replace({"Bilmiyorum": 0.0,
                                                      "Başlangıç": 0.10,
                                                      "Orta": 0.20,
                                                     "İleri": 0.30})

test["Ingilizce Seviyeniz?"] = test["Ingilizce Seviyeniz?"].replace({"Bilmiyorum": 0.0,
                                                      "Başlangıç": 0.10,
                                                      "Orta": 0.20,
                                                     "İleri": 0.30})

# %%
for i in train.columns:
    print("Column Name: ",i)
    print(train[i].value_counts())
    print("\n\n")
# Out:
# Column Name:  Basvuru Yili
# Basvuru Yili
# 0.7    11594
# 0.3    10325
# 0.1     7804
# 0.6     7760
# 0.8     7622
# 0.5     7248
# 0.0     6454
# 0.2     5213
# 0.4     1105
# Name: count, dtype: int64
#
#
#
# Column Name:  Degerlendirme Puani
# Degerlendirme Puani
# 28.000000     2063
# 22.000000     2041
# 18.000000     1995
# 24.000000     1785
# 12.000000     1740
#               ...
# 100.000000       2
# 102.000000       2
# 89.000000        1
# 95.000000        1
# 32.086466        1
# Name: count, Length: 98, dtype: int64
#
#
#
# Column Name:  Cinsiyet
# Cinsiyet
# 1.0    32905
# 0.0    32220
# Name: count, dtype: int64
#
#
#
# Column Name:  Dogum Yeri
# Dogum Yeri
# İstanbul             8788
# Ankara               4086
# İzmir                2198
# Istanbul             1912
# Bursa                1831
#                      ...
# UZUNKÖPRÜ EDİRNE        1
# Çamlıyayla              1
# ANKARA / ALTINDAĞ       1
# ERZURUM-İSPİR           1
# Izmir Konak             1
# ...

# %%
from sklearn.impute import KNNImputer
import pandas as pd

def knn_impute(df, n_neighbors=5):
    non_empty_columns = df.columns[df.isnull().mean() < 1.0]
    df_reduced = df[non_empty_columns].copy()

    for col in df_reduced.select_dtypes(include='object').columns:
        df_reduced[col] = df_reduced[col].astype('category').cat.codes

    knn_imputer = KNNImputer(n_neighbors=n_neighbors)
    df_imputed = pd.DataFrame(knn_imputer.fit_transform(df_reduced), columns=df_reduced.columns)
    
    for col in df.select_dtypes(include='object').columns:
        if col in df_reduced.columns:
            df_imputed[col] = df_imputed[col].round().astype(int).map(
                dict(enumerate(df[col].astype('category').cat.categories))
            )
    
    for col in df.columns:
        if col not in df_imputed.columns:
            df_imputed[col] = np.nan
    
    df_imputed = df_imputed[df.columns]
    
    return df_imputed

# %%
# Apply the modified imputation function
df_train_imputed = knn_impute(train, n_neighbors=9)
df_test_imputed = knn_impute(test, n_neighbors=9)

# Check the length of the imputed datasets
print(f"Length of train_df after imputation: {len(df_train_imputed)}")
print(f"Length of test_df after imputation: {len(df_test_imputed)}")
# Out:
# Length of train_df after imputation: 65125
# Length of test_df after imputation: 11049

# %%
from sklearn.preprocessing import OrdinalEncoder

cat_cols_train = df_train_imputed.select_dtypes(include=['object']).columns
cat_cols_train = cat_cols_train[cat_cols_train != 'Degerlendirme Puani']

ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

df_train_imputed[cat_cols_train] = ordinal_encoder.fit_transform(df_train_imputed[cat_cols_train].astype(str))
df_test_imputed[cat_cols_train] = ordinal_encoder.transform(df_test_imputed[cat_cols_train].astype(str))

# %%
train = df_train_imputed
test = df_test_imputed

# %%
train[['Lise Turu', 'Anne Sektor','Anne Calisma Durumu','Baba Calisma Durumu','Baba Sektor','Spor Dalindaki Rolunuz Nedir?']]
# Out:
#        Lise Turu  Anne Sektor  Anne Calisma Durumu  Baba Calisma Durumu  \
# 0            0.0          2.0                  2.0                  0.0
# 1            0.0          1.0                  1.0                  0.0
# 2            1.0          2.0                  2.0                  1.0
# 3            3.0          2.0                  2.0                  0.0
# 4            4.0          2.0                  2.0                  0.0
# ...          ...          ...                  ...                  ...
# 65120        1.0          2.0                  2.0                  1.0
# 65121        1.0          2.0                  2.0                  1.0
# 65122        1.0          2.0                  2.0                  2.0
# 65123        1.0          3.0                  1.0                  1.0
# 65124        1.0          2.0                  2.0                  1.0
#
#        Baba Sektor  Spor Dalindaki Rolunuz Nedir?
# 0              2.0                            1.0
# ...

# %%
test[['Lise Turu', 'Anne Sektor','Anne Calisma Durumu','Baba Calisma Durumu','Baba Sektor','Spor Dalindaki Rolunuz Nedir?']]
# Out:
#        Lise Turu  Anne Sektor  Anne Calisma Durumu  Baba Calisma Durumu  \
# 0            1.0          3.0                  1.0                  1.0
# 1            1.0          2.0                  2.0                  1.0
# 2            4.0          2.0                  2.0                  2.0
# 3            1.0          2.0                  2.0                  1.0
# 4            4.0          1.0                  1.0                  1.0
# ...          ...          ...                  ...                  ...
# 11044        1.0          2.0                  2.0                  2.0
# 11045        1.0          2.0                  2.0                  1.0
# 11046        4.0          2.0                  2.0                  1.0
# 11047        1.0          2.0                  2.0                  1.0
# 11048        1.0          2.0                  2.0                  1.0
#
#        Baba Sektor  Spor Dalindaki Rolunuz Nedir?
# 0              0.0                            4.0
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65125 entries, 0 to 65124
# Data columns (total 44 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Basvuru Yili                                               65125 non-null  float64
#  1   Degerlendirme Puani                                        65125 non-null  float64
#  2   Cinsiyet                                                   65125 non-null  float64
#  3   Dogum Yeri                                                 65125 non-null  float64
#  4   Ikametgah Sehri                                            65125 non-null  float64
#  5   Universite Adi                                             65125 non-null  float64
#  6   Universite Turu                                            65125 non-null  float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11049 entries, 0 to 11048
# Data columns (total 43 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Basvuru Yili                                               11049 non-null  float64
#  1   Cinsiyet                                                   11049 non-null  float64
#  2   Dogum Yeri                                                 11049 non-null  float64
#  3   Ikametgah Sehri                                            11049 non-null  float64
#  4   Universite Adi                                             11049 non-null  float64
#  5   Universite Turu                                            11049 non-null  float64
#  6   Burslu ise Burs Yuzdesi                                    11049 non-null  float64
# ...

# %%
#train[train.columns] = train[train.columns].astype(float)
#test[test.columns] = test[test.columns].astype(float)

# %%
for i in train.columns:
    print("Column Name: ",i)
    print(train[i].value_counts())
    print("\n\n")
# Out:
# Column Name:  Basvuru Yili
# Basvuru Yili
# 0.7    11594
# 0.3    10325
# 0.1     7804
# 0.6     7760
# 0.8     7622
# 0.5     7248
# 0.0     6454
# 0.2     5213
# 0.4     1105
# Name: count, dtype: int64
#
#
#
# Column Name:  Degerlendirme Puani
# Degerlendirme Puani
# 28.000000     2063
# 22.000000     2041
# 18.000000     1995
# 24.000000     1785
# 12.000000     1740
#               ...
# 100.000000       2
# 102.000000       2
# 89.000000        1
# 95.000000        1
# 32.086466        1
# Name: count, Length: 98, dtype: int64
#
#
#
# Column Name:  Cinsiyet
# Cinsiyet
# 1.0    32905
# 0.0    32220
# Name: count, dtype: int64
#
#
#
# Column Name:  Dogum Yeri
# Dogum Yeri
# 2113.0    8788
# 135.0     4086
# 2160.0    2198
# 686.0     1912
# 361.0     1831
#           ...
# 1337.0       1
# 1969.0       1
# 45.0         1
# 462.0        1
# 697.0        1
# Name: count, Length: 2230, dtype: int64
#
#
#
# Column Name:  Ikametgah Sehri
# Ikametgah Sehri
# 309.0    17164
# ...

# %%
# !pip install xgboost
# !pip install lightgbm
# !pip install catboost

# %%
del(train["Burslu ise Burs Yuzdesi"])
del(train["Daha Once Baska Bir Universiteden Mezun Olmus"])
del(train["Stk Projesine Katildiniz Mi?"])
del(train["Ingilizce Seviyeniz?"])
del(test["Burslu ise Burs Yuzdesi"])
del(test["Daha Once Baska Bir Universiteden Mezun Olmus"])
del(test["Stk Projesine Katildiniz Mi?"])
del(test["Ingilizce Seviyeniz?"])

# %%
# Silmek istediğiniz sütunlar
columns_to_delete = [
    "Burslu ise Burs Yuzdesi",
    "Daha Once Baska Bir Universiteden Mezun Olmus",
    "Lise Adi Diger",
    "Lise Bolum Diger",
    "Uye Oldugunuz Kulubun Ismi",
    "Stk Projesine Katildiniz Mi?",
    "Ingilizce Seviyeniz?",
    "Daha Önceden Mezun Olunduysa",
    "Mezun Olunan Üniversite"
]

# Mevcut sütunları kontrol edin
existing_columns = [col for col in columns_to_delete if col in train.columns]

# Mevcut olmayan sütunları belirleyin
non_existing_columns = [col for col in columns_to_delete if col not in train.columns]

print("Mevcut Olmayan Sütunlar:", non_existing_columns)
# Silmek istediğiniz sütunlar arasından mevcut olanları seçin
columns_to_delete_existing = [col for col in columns_to_delete if col in train.columns]

# Mevcut sütunları veri setlerinden silin
train = train.drop(columns=columns_to_delete_existing, errors='ignore')
test = test.drop(columns=columns_to_delete_existing, errors='ignore')
# Out:
# Mevcut Olmayan Sütunlar: ['Burslu ise Burs Yuzdesi', 'Daha Once Baska Bir Universiteden Mezun Olmus', 'Stk Projesine Katildiniz Mi?', 'Ingilizce Seviyeniz?', 'Daha Önceden Mezun Olunduysa', 'Mezun Olunan Üniversite']

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65125 entries, 0 to 65124
# Data columns (total 37 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Basvuru Yili                                               65125 non-null  float64
#  1   Degerlendirme Puani                                        65125 non-null  float64
#  2   Cinsiyet                                                   65125 non-null  float64
#  3   Dogum Yeri                                                 65125 non-null  float64
#  4   Ikametgah Sehri                                            65125 non-null  float64
#  5   Universite Adi                                             65125 non-null  float64
#  6   Universite Turu                                            65125 non-null  float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11049 entries, 0 to 11048
# Data columns (total 36 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Basvuru Yili                                               11049 non-null  float64
#  1   Cinsiyet                                                   11049 non-null  float64
#  2   Dogum Yeri                                                 11049 non-null  float64
#  3   Ikametgah Sehri                                            11049 non-null  float64
#  4   Universite Adi                                             11049 non-null  float64
#  5   Universite Turu                                            11049 non-null  float64
#  6   Burs Aliyor mu?                                            11049 non-null  float64
# ...

# %%
"""import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import xgboost as XGBRegressor

X_train = train.drop(['id', 'Degerlendirme Puani'], axis=1)
y_train = train['Degerlendirme Puani']
X_test = test.drop(['id'], axis=1)

from xgboost import XGBRegressor

# Model oluşturma ve eğitim
xgb_model = XGBRegressor(random_state=42)
xgb_model.fit(X_train, y_train)

# Tahminler yapma
y_pred_xgb = xgb_model.predict(X_test)


submission8 = pd.DataFrame({
    'id': test['id'].astype(int),  
    'Degerlendirme Puani': y_pred_xgb 
})

submission8.to_csv('submission1.csv', index=False)"""
# Out:
# "import pandas as pd\nfrom sklearn.model_selection import train_test_split\nfrom sklearn.metrics import classification_report, accuracy_score\nimport xgboost as XGBRegressor\n\nX_train = train.drop(['id', 'Degerlendirme Puani'], axis=1)\ny_train = train['Degerlendirme Puani']\nX_test = test.drop(['id'], axis=1)\n\nfrom xgboost import XGBRegressor\n\n# Model oluşturma ve eğitim\nxgb_model = XGBRegressor(random_state=42)\nxgb_model.fit(X_train, y_train)\n\n# Tahminler yapma\ny_pred_xgb = xgb_model.predict(X_test)\n\n\nsubmission8 = pd.DataFrame({\n    'id': test['id'].astype(int),  \n    'Degerlendirme Puani': y_pred_xgb \n})\n\nsubmission8.to_csv('submission1.csv', index=False)"

# %%
"""import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error
from catboost import CatBoostRegressor

# Verileri hazırla
X_train = train.drop(['id', 'Degerlendirme Puani'], axis=1)
y_train = train['Degerlendirme Puani']
X_test = test.drop(['id'], axis=1)  # 'Degerlendirme Puani' kolonu test setinde yok, sadece 'id'yi kaldır

# Modeli oluştur ve eğit

from catboost import CatBoostRegressor

model = CatBoostRegressor(
    iterations=20000,
    learning_rate=0.07,
    depth=6,
    l2_leaf_reg=3,
    loss_function='RMSE',
    eval_metric='RMSE',
    random_seed=42,
    verbose=100
)


cat_model = model
cat_model.fit(X_train, y_train)

# Test seti üzerinde tahminler yap
y_pred_cat = cat_model.predict(X_test)

# Tahmin sonuçlarını CSV dosyasına yaz
submission = pd.DataFrame({
    'id': test['id'].astype(int),  
    'Degerlendirme Puani': y_pred_cat 
})
submission.to_csv('submission22222.csv', index=False)

# Model performansını değerlendirme (eğitim verisi üzerinde)
scores = cross_val_score(cat_model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
mse = -scores.mean()
rmse = np.sqrt(mse)

# Sonuçları yazdır
print('CatBoostRegressor Modeli:')
print(f'  Ortalama Mean Squared Error (MSE): {mse}')
print(f'  Ortalama Root Mean Squared Error (RMSE): {rmse}')
"""
# Out:
# "import numpy as np\nimport pandas as pd\nfrom sklearn.model_selection import train_test_split, cross_val_score\nfrom sklearn.metrics import mean_squared_error\nfrom catboost import CatBoostRegressor\n\n# Verileri hazırla\nX_train = train.drop(['id', 'Degerlendirme Puani'], axis=1)\ny_train = train['Degerlendirme Puani']\nX_test = test.drop(['id'], axis=1)  # 'Degerlendirme Puani' kolonu test setinde yok, sadece 'id'yi kaldır\n\n# Modeli oluştur ve eğit\n\nfrom catboost import CatBoostRegressor\n\nmodel = CatBoostRegressor(\n    iterations=20000,\n    learning_rate=0.07,\n    depth=6,\n    l2_leaf_reg=3,\n    loss_function='RMSE',\n    eval_metric='RMSE',\n    random_seed=42,\n    verbose=100\n)\n\n\ncat_model = model\ncat_model.fit(X_train, y_train)\n\n# Test seti üzerinde tahminler yap\ny_pred_cat = cat_model.predict(X_test)\n\n# Tahmin sonuçlarını CSV dosyasına yaz\nsubmission = pd.DataFrame({\n    'id': test['id'].astype(int),  \n    'Degerlendirme Puani': y_pred_cat \n})\nsubmis
# ...

# %%
for i in train.columns:
    print("Column Name: ",i)
    print(train[i].value_counts())
    print("\n\n")
# Out:
# Column Name:  Basvuru Yili
# Basvuru Yili
# 0.7    11594
# 0.3    10325
# 0.1     7804
# 0.6     7760
# 0.8     7622
# 0.5     7248
# 0.0     6454
# 0.2     5213
# 0.4     1105
# Name: count, dtype: int64
#
#
#
# Column Name:  Degerlendirme Puani
# Degerlendirme Puani
# 28.000000     2063
# 22.000000     2041
# 18.000000     1995
# 24.000000     1785
# 12.000000     1740
#               ...
# 100.000000       2
# 102.000000       2
# 89.000000        1
# 95.000000        1
# 32.086466        1
# Name: count, Length: 98, dtype: int64
#
#
#
# Column Name:  Cinsiyet
# Cinsiyet
# 1.0    32905
# 0.0    32220
# Name: count, dtype: int64
#
#
#
# Column Name:  Dogum Yeri
# Dogum Yeri
# 2113.0    8788
# 135.0     4086
# 2160.0    2198
# 686.0     1912
# 361.0     1831
#           ...
# 1337.0       1
# 1969.0       1
# 45.0         1
# 462.0        1
# 697.0        1
# Name: count, Length: 2230, dtype: int64
#
#
#
# Column Name:  Ikametgah Sehri
# Ikametgah Sehri
# 309.0    17164
# ...

# %%
"""import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error
import xgboost as xgb

# Verileri hazırla
X_train = train.drop(['id', 'Degerlendirme Puani'], axis=1)
y_train = train['Degerlendirme Puani']
X_test = test.drop(['id'], axis=1)  # 'Degerlendirme Puani' kolonu test setinde yok, sadece 'id'yi kaldır

# Modeli oluştur ve eğit
model = xgb.XGBRegressor(
    n_estimators=10000,               # `iterations` yerine `n_estimators`
    learning_rate=0.05,
    max_depth=8,                     # `depth` yerine `max_depth`
    reg_lambda=3,                    # `l2_leaf_reg` yerine `reg_lambda`
    objective='reg:squarederror',    # `loss_function` yerine `objective`
    eval_metric='rmse',              # XGBoost'ta `RMSE` küçük harflerle yazılır
    random_state=42,
    verbose=50
)

model.fit(X_train, y_train)

# Test seti üzerinde tahminler yap
y_pred = model.predict(X_test)

# Tahmin sonuçlarını CSV dosyasına yaz
submission = pd.DataFrame({
    'id': test['id'].astype(int),  
    'Degerlendirme Puani': y_pred 
})
submission.to_csv('submission_xgb.csv', index=False)

# Model performansını değerlendirme (eğitim verisi üzerinde)
scores = cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
mse = -scores.mean()
rmse = np.sqrt(mse)

# Sonuçları yazdır
print('XGBoost Modeli:')
print(f'  Ortalama Mean Squared Error (MSE): {mse}')
print(f'  Ortalama Root Mean Squared Error (RMSE): {rmse}')
"""
# Out:
# "import numpy as np\nimport pandas as pd\nfrom sklearn.model_selection import train_test_split, cross_val_score\nfrom sklearn.metrics import mean_squared_error\nimport xgboost as xgb\n\n# Verileri hazırla\nX_train = train.drop(['id', 'Degerlendirme Puani'], axis=1)\ny_train = train['Degerlendirme Puani']\nX_test = test.drop(['id'], axis=1)  # 'Degerlendirme Puani' kolonu test setinde yok, sadece 'id'yi kaldır\n\n# Modeli oluştur ve eğit\nmodel = xgb.XGBRegressor(\n    n_estimators=10000,               # `iterations` yerine `n_estimators`\n    learning_rate=0.05,\n    max_depth=8,                     # `depth` yerine `max_depth`\n    reg_lambda=3,                    # `l2_leaf_reg` yerine `reg_lambda`\n    objective='reg:squarederror',    # `loss_function` yerine `objective`\n    eval_metric='rmse',              # XGBoost'ta `RMSE` küçük harflerle yazılır\n    random_state=42,\n    verbose=50\n)\n\nmodel.fit(X_train, y_train)\n\n# Test seti üzerinde tahminler yap\ny_pred = model.predi
# ...
